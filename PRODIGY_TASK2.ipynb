# %% [markdown]
# <a href="https://colab.research.google.com/github/karthikeyaniii/genai_prodigy/blob/main/PRODIGY_TASK2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install diffusers transformers accelerate torch torchvision
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.7/2.7 MB 10.0 MB/s eta 0:00:00
# ...

# %%
from diffusers import StableDiffusionPipeline
import torch


pipe = StableDiffusionPipeline.from_pretrained("runwayml/stable-diffusion-v1-5")



def generate_stable_diffusion_image(prompt: str):

    image = pipe(prompt).images[0]

    return image
# Out:
# Loading pipeline components...:   0%|          | 0/7 [00:00<?, ?it/s]

# %%
prompt = "A futuristic city skyline at sunset with flying cars"

image = generate_stable_diffusion_image(prompt)

image.show()

image.save("stable_diffusion_output.png")
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]
